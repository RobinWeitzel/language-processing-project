# %%
import pandas as pd

tweets = pd.read_json('../Datasets/tweets.json')

# %%
import urllib.request
import os
from tqdm import tqdm_notebook as tqdm
from PIL import Image, ImageOps

def downloadImages(df, path):
    # Create folder if it does not yet exist
    if not os.path.isdir(path):
        os.mkdir(path)
                
    counter = 0
    
    t = tqdm(df.iterrows(), total=len(df))
    
    for i, row in t:
        img_url = row['url']
        name = img_url.split('/')[len(img_url.split('/')) - 1]
        full_path = path + "/" + name
        if not os.path.exists(full_path):
            # Download the image if it does not yet exist
            try:
                urllib.request.urlretrieve(img_url, full_path)
                image = Image.open(full_path)
                thumb = ImageOps.fit(image, (227, 227), Image.ANTIALIAS)
                thumb.save(full_path)
                counter += 1
                
                t.set_description(str(counter) + "/" + str(i) + " successfully downloaded")
            except:
                continue
        
        # Overwrite the URL with the name of the image if the image exists
        if os.path.exists(full_path):
            tweets.at[i, 'url'] = full_path
        
print("Downloading images")
downloadImages(tweets, "../Datasets/images")
# Out:
# Downloading images
# HBox(children=(IntProgress(value=0, max=60803), HTML(value='')))

# %%
tweets.at[1, 'url']
# Out:
# 'https://pbs.twimg.com/media/D6CqnZrW0AIvWDU.jpg'

# %%
tweets
# Out:
#                                                  content                date  \
# 0      RT @AvaKoxxx: #sneakpeak of my #onlyfans #subs... 2019-05-09 13:08:11
# 1      RT @ironmansbest: Last night, I dreamt, we had... 2019-05-09 13:08:13
# 2      RT @G2Mikyx: Ready for MSI! https://t.co/484jB... 2019-05-09 13:08:13
# 3      RT @reggiegotlag: If you didn’t scream when th... 2019-05-09 13:08:14
# 4      RT @bunnyarchive: the little slide https://t.c... 2019-05-09 13:08:14
# 5      RT @Yaaashu_8: Thank you @anirudhofficial fore... 2019-05-09 13:08:14
# 6      Imagine Ari performing 7 Rings in this outfit ... 2019-05-09 13:08:15
# 7      RT @kylosdaniel: TOM IS IN HIS SPIDEY SUIT AND... 2019-05-09 13:08:16
# 8      RT @Asmali77: Ouch! That’s gonna hurt. #Eastle... 2019-05-09 13:08:16
# 9      RT @discordapp: i present our CEO... https://t... 2019-05-09 13:08:17
# 10     RT @BTSBangtan_Mia: #ARMYConcertForTaehyung  w... 2019-05-09 13:08:17
# 11     RT @PBBabscbn: Happy birthday to our Dance-ire... 2019-05-09 13:08:17
# 12     RT @BrymOlawale: Here’s to 33, age is grace!!!... 2019-05-09 13:08:18
# 13     RT @Katykay2018: "Shall we help her up?"\n\nNi... 2019-05-09 13:08:18
# 14        RT @ChrisEvans: Part 2 https://t.co/Vm5FNMvncr 2019-05-09 13:08:18
# 15     RT @puntinational: RT when you spot the irony.... 2019-05-09 13:08:19
# 16     RT @lovelyyukei: OH MY GOD WINWIN SOUNDS SO GO... 2019-05-09 13:08:19
# 60792  RT @flrtjmn: only OT7 stans can rt this https:... 2019-05-14 09:26:13
# 60793  RT @BTS_twt: I was so happy..\n#JIMIN\n#Jk htt... 2019-05-14 09:26:14
# 60794  Mt Kenya United's woes pile with latest walkov... 2019-05-14 09:26:15
# 60795  Check out my class in #GranblueFantasy! https:... 2019-05-14 09:26:17
# 60796  OMG, this channel is awesome! https://t.co/zU5... 2019-05-14 09:26:17
# 60797  RT @Jamesbay77: GOOD MORNING LONDON ! https://... 2019-05-14 09:26:17
# 60798  RT @Anti: If this pic is real this a powerful ... 2019-05-14 09:26:17
# 60799  RT @NBCTheVoice: When the @jonasbrothers and @... 2019-05-14 09:26:17
# 60800  RT @TXT_members: We've arrived in Orlando! \nS... 2019-05-14 09:26:20
# 60801  RT @Mens_Corner_: Field Goal percentage: 0% ht... 2019-05-14 09:26:20
# 60802  Cuteness Overloaded\n\n@Siva_Kartikeyan Anna h... 2019-05-14 09:26:21
#
#        idtweets                                      url
# 0             1  ../Datasets/images/LQKDjBnLoo8b4VmQ.jpg
# 1             2   ../Datasets/images/D6CqnZrW0AIvWDU.jpg
# 2             3   ../Datasets/images/D6HthAIUcAAvpYk.jpg
# 3             4  ../Datasets/images/JPJd7aS_jHpyFwdA.jpg
# 4             5  ../Datasets/images/EPmSWBrU6tHcwKCY.jpg
# 5             6  ../Datasets/images/UPwGjTwpOQ70SS0C.jpg
# 6             7   ../Datasets/images/D6Hums5WAAAI9kv.jpg
# 7             8  ../Datasets/images/_kzbdat2JgItYtbf.jpg
# 8             9  ../Datasets/images/kSdFQ6dQ2wCIKsaW.jpg
# 9            10   ../Datasets/images/D6E9pvNUYAAZ-t3.png
# 10           11  ../Datasets/images/KvqAcie-iQ1_dNUJ.jpg
# 11           12   ../Datasets/images/D6Hlzf0U0AAqTgO.jpg
# 12           13   ../Datasets/images/D6GQR5cWAAAudYd.jpg
# 13           14  ../Datasets/images/jphRZVTH5STJ_nfk.jpg
# 14           15  ../Datasets/images/i1SwUN7gkihvAAOe.jpg
# 15           16   ../Datasets/images/D6CpqiWUUAAtDf7.jpg
# 16           17  ../Datasets/images/dru9-p4UpleQ8aKS.jpg
# 17           18  ../Datasets/images/djE6wMeRcfRLx92a.jpg
# 18           19  ../Datasets/images/-tebDE0nqU1HSrvP.jpg
# 19           20   ../Datasets/images/D6HuoLZW0AMQXHO.jpg
# 20           21  ../Datasets/images/CNYiRzPX7pwwDdAg.jpg
# 21           22   ../Datasets/images/D59VecAXkAAy_bf.jpg
# 22           23  ../Datasets/images/SoGpeqrTW0Y2n19B.jpg
# 23           24   ../Datasets/images/D6Hunl0XsAEi9km.jpg
# 24           25  ../Datasets/images/hhMhWhJx0WrAY0u7.jpg
# 25           26   ../Datasets/images/D6HpqPhUEAAbNeI.jpg
# 26           27  ../Datasets/images/0KilH_TdHgLGmefZ.jpg
# 27           28   ../Datasets/images/D6F2weAUYAAzVSJ.jpg
# 28           29  ../Datasets/images/YE2kIqZIfIGbTuvy.jpg
# 29           30  ../Datasets/images/huIaNuoEPCdUrqN9.jpg
# ...         ...                                      ...
# 60773     60774  ../Datasets/images/NeDnGE0zdJVvNZ-A.jpg
# 60774     60775  ../Datasets/images/_FCWrrmCsRr3uKWr.jpg
# 60775     60776  ../Datasets/images/rZvWNz5IALRm7jLs.jpg
# 60776     60777   ../Datasets/images/D6brZHeUUAAIhTG.jpg
# 60777     60778  ../Datasets/images/NjTzKqXG5wor6Ujh.jpg
# 60778     60779  ../Datasets/images/hGQdfZQJVqWM5oQm.jpg
# 60779     60780   ../Datasets/images/D6f_t-SV4AUP6sK.jpg
# 60780     60781   ../Datasets/images/DeK1ACIWAAICrMk.jpg
# 60781     60782   ../Datasets/images/D6dKRiRW4AAoQ6h.jpg
# 60782     60783  ../Datasets/images/eClRvFB0ty0orLXi.jpg
# 60783     60784  ../Datasets/images/YHe6JwMzEft2yKok.jpg
# 60784     60785   ../Datasets/images/D6ahILoUcAAyOvb.png
# 60785     60786   ../Datasets/images/D6gruCiW0AAGk_B.jpg
# 60786     60787   ../Datasets/images/D6gYETgWkAApVKC.jpg
# 60787     60788   ../Datasets/images/D6gKcVXUYAAVfQW.jpg
# 60788     60789   ../Datasets/images/D6dpFgTW0AARlwX.jpg
# 60789     60790  ../Datasets/images/QUUK2j10HuTibN4t.jpg
# 60790     60791   ../Datasets/images/D6gruzdWsAAZzri.png
# 60791     60792   ../Datasets/images/D6dRvpRU0AgKd9O.jpg
# 60792     60793   ../Datasets/images/D6ct1yrU0AE5toj.jpg
# 60793     60794  ../Datasets/images/8DfeyKVt67p8Bajs.jpg
# 60794     60795   ../Datasets/images/D6grv9fWwAAbD90.jpg
# 60795     60796   ../Datasets/images/D6grwOPUYAAG4-D.jpg
# 60796     60797   ../Datasets/images/D6grwItW4AADFCx.png
# 60797     60798   ../Datasets/images/D6gq4rFWsAEvUKY.jpg
# 60798     60799   ../Datasets/images/D6U0Y5yWkAA9Z-h.jpg
# 60799     60800   ../Datasets/images/D6frDlLU8AAPWNb.jpg
# 60800     60801  ../Datasets/images/DVREHjnX0aCU9Jao.jpg
# 60801     60802  ../Datasets/images/4whOsKEF_SoCJgxk.jpg
# 60802     60803   ../Datasets/images/D6grwZpUIAE77Fn.jpg
#
# [60803 rows x 4 columns]

# %%
thumb = ImageOps.fit(image, (227, 227), Image.ANTIALIAS)
thumb

# %%
thumb.save(path)
